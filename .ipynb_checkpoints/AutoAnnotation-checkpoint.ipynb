# %% [markdown]
# # Auto Annotation using Rembg for training in yolo v8 *(Test for simple object)*

# %% [markdown]
# ### Importing necessary libraries

# %%
from rembg import remove
from tqdm import tqdm
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import cv2
from scipy.spatial import ConvexHull
import json

# %% [markdown]
# ### Declaring input and output path and observing input image

# %%
input_path = 'input.jpg'

# %% [markdown]
# #### Rotated by 90 degree initially so resolving that

# %%
img = Image.open(input_path)
plt.imshow(np.rot90(np.asarray(img),k=3))
plt.show()

# %% [markdown]
# ### Running remove function from rembg i.e Removing background and observing it

# %%
rem_bg = remove(img)
plt.imshow(np.array(output))

# %% [markdown]
# ### Masking given background removed image

# %%
input = np.array(output)

# %%
alpha_channel = input[:, :, 3]
mask = (alpha_channel != 0).astype(np.uint8)

# %%
plt.imshow(mask,cmap="gray")

# %% [markdown]
# ### Finding coordinates with object and making a bounding box

# %%
# Find the coordinates of all the '1' values
coords = np.argwhere(mask == 1)

# Find the minimum and maximum row and column values
min_row, min_col = np.min(coords, axis=0)
max_row, max_col = np.max(coords, axis=0)

points = np.dstack((c,v))
# Create the bounding polygon as a list of vertices
vertices = np.array([
    (min_row, min_col),
    (min_row, max_col),
    (max_row, max_col),
    (max_row, min_col)
])

x = min_col
y = min_row
w = max_col - min_col
h = max_row - min_row

print(f"x: {x}, y: {y}, width: {w}, height: {h}")
# Out:
# x: 101, y: 436, width: 1050, height: 804

# %% [markdown]
# ### Shows rotated Image

# %%
# Compute the convex hull of the coords
hull = ConvexHull(coords, qhull_options="QJ")

# Plot the coords and the convex hull
plt.plot(coords[:, 0], coords[:, 1], 'o', label='Points')
plt.plot(coords[hull.vertices, 0], coords[hull.vertices, 1], 'r--', lw=2, label='Convex Hull')
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting all ie. bouding box, masked object and hull

# %%
fig,ax = plt.subplots()
ax.imshow(mask,cmap="gray")
rect = plt.Rectangle((x,y), w, h, fill= False,edgecolor = 'red',)
plt.plot(coords[hull.vertices, 1], coords[hull.vertices, 0],"w")
ax.add_patch(rect)

# %%
fig,ax = plt.subplots()
ax.imshow(np.array(Image.open(input_path)))
rect = plt.Rectangle((y,x), h, w, fill= False,edgecolor = 'red',)
polygon = plt.Polygon(convex_hull_vertices,fill= False,edgecolor = 'white',)
ax.add_patch(polygon)
ax.add_patch(rect)

# %%
annotation_data = {
    "image_id": "0",
    "annotations": [
        {
            "category": "bag",
            "segmentation": hull.vertices.tolist(),
            "bbox": [x,y,h,w]
        }
    ]
}
with open('annotation.json', 'w') as f:
    json.dump(annotation_data, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[171], line 12
#       1 annotation_data = {
#       2     "image_id": "0",
#       3     "annotations": [
#    (...)
#       9     ]
#      10 }
#      11 with open('annotation.json', 'w') as f:
# ---> 12     json.dump(annotation_data, f)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# ...
